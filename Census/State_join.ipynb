# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn

# %%
# Store filepath in a variable
file_one = "census_data.csv"
file_two = "large_brewery_file.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")
# Show just the header
file_one_df.head()
# Out:
#          Name  Population  Median Age  Household Income  Per Capita Income  \
# 0     Alabama   4799277.0        38.1           43253.0            23680.0
# 1      Alaska    720316.0        33.6           70760.0            32651.0
# 2     Arizona   6479703.0        36.3           49774.0            25358.0
# 3    Arkansas   2933369.0        37.5           40768.0            22170.0
# 4  California  37659181.0        35.4           61094.0            29527.0
#
#    Number of Males  Number of Females
# 0        2328592.0          2470685.0
# 1         375798.0           344518.0
# 2        3221367.0          3258336.0
# 3        1439862.0          1493507.0
# 4       18726468.0         18932713.0

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
file_two_df = pd.read_csv(file_two, encoding="ISO-8859-1")
# Show just the header
file_two_df.head()
# Out:
#                      brewery_name                    address  \
# 0              49th State Brewing              717 W 3rd Ave
# 1           Arctic Brewing Supply         8401 Sandlewood Pl
# 2              Arkose Brewery Llc           650 E Steel Loop
# 3  Baranof Island Brewing Company               215 Smith St
# 4   Bearpaw River Brewing Company  4605 E Palmer Wasilla Hwy
#
#                                           categories       city country  \
# 0                                            Brewery  Anchorage      US
# 1  miscellaneous shop, Winemaking Equipment & Sup...  Anchorage      US
# 2      Brew Pubs, Brewers, Beer & Ale, Liquor Stores     Palmer      US
# 3                            Breweries, Food & Drink      Sitka      US
# 4                            Breweries, Food & Drink    Wasilla      US
#
#   zip_code state    Name        lat        long
# 0    99501    AK  Alaska        NaN         NaN
# 1    99507    AK  Alaska  61.145509 -149.852717
# ...

# %%
print(file_two_df.columns)
# Out:
# Index(['brewery_name', 'address', 'categories', 'city', 'country', 'zip_code',
#        'state', 'Name', 'lat', 'long'],
#       dtype='object')

# %%
# Merge two dataframes using an inner join
merge_table = pd.merge(file_one_df, file_two_df, on="Name")
merge_table.to_csv("Joined_File.csv", index=False, header=True)
merge_table
# Out:
#            Name  Population  Median Age  Household Income  Per Capita Income  \
# 0       Alabama   4799277.0        38.1           43253.0            23680.0
# 1       Alabama   4799277.0        38.1           43253.0            23680.0
# 2       Alabama   4799277.0        38.1           43253.0            23680.0
# 3       Alabama   4799277.0        38.1           43253.0            23680.0
# 4       Alabama   4799277.0        38.1           43253.0            23680.0
# 5       Alabama   4799277.0        38.1           43253.0            23680.0
# 6       Alabama   4799277.0        38.1           43253.0            23680.0
# 7       Alabama   4799277.0        38.1           43253.0            23680.0
# 8       Alabama   4799277.0        38.1           43253.0            23680.0
# 9       Alabama   4799277.0        38.1           43253.0            23680.0
# 10      Alabama   4799277.0        38.1           43253.0            23680.0
# ...

# %%
states = merge_table["Name"]
number_breweries = merge_table["Name"].value_counts()

# Configure plot and ticks
plt.figure(figsize=(20,3))
number_breweries.plot(kind="bar", facecolor="seagreen")

# Set textual properties
plt.title("Number of Breweries by State")
plt.ylabel("Number of Breweries")
plt.xlabel("State")

# Show plot
plt.show()
plt.tight_layout()

# %%
num_brew = number_breweries
grouped = merge_table.groupby("Name")
median_age = grouped["Median Age"].mean()

plt.scatter(num_brew, median_age, marker="o", facecolors="violet", edgecolors="black")

plt.ylim(29, 44)

# Set the upper and lower limits of our x axis
plt.xlim(0, 910)

# Create a title, x label, and y label for our chart
plt.title("Number of Breweries vs. Median Age")
plt.xlabel("Number of Breweries")
plt.ylabel("Median Age (in years)")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
grouped = merge_table.groupby("Name")
median_age = grouped["Median Age"].mean()
median_age
# Out:
# Name
# Alabama                 38.1
# Alaska                  33.6
# Arizona                 36.3
# Arkansas                37.5
# California              35.4
# Colorado                36.1
# Connecticut             40.2
# Delaware                38.9
# District of Columbia    33.8
# Florida                 41.0
# Georgia                 35.6
# Hawaii                  38.3
# Idaho                   34.9
# Illinois                36.8
# Indiana                 37.1
# Iowa                    38.1
# Kansas                  36.0
# Kentucky                38.2
# Louisiana               36.0
# Maine                   43.2
# Maryland                38.0
# Massachusetts           39.2
# Michigan                39.1
# Minnesota               37.6
# Mississippi             36.2
# Missouri                38.0
# Montana                 39.9
# Nebraska                36.3
# Nevada                  36.6
# New Hampshire           41.5
# New Jersey              39.1
# New Mexico              36.7
# ...

# %%
number_breweries = merge_table["Name"].value_counts()
grouped = merge_table.groupby("Name")
population = grouped["Population"].mean()

population = pd.DataFrame({"Number of Breweries": number_breweries,
                       "Population": population
                      })

population
# Out:
#                       Number of Breweries  Population
# Alabama                                67   4799277.0
# Alaska                                 27    720316.0
# Arizona                               155   6479703.0
# Arkansas                               56   2933369.0
# California                            902  37659181.0
# Colorado                              308   5119329.0
# Connecticut                            53   3583561.0
# Delaware                               24    908446.0
# District of Columbia                   14    619371.0
# Florida                               272  19091156.0
# Georgia                                77   9810417.0
# Hawaii                                 24   1376298.0
# Idaho                                  46   1583364.0
# Illinois                              234  12848554.0
# Indiana                               144   6514861.0
# Iowa                                  106   3062553.0
# ...

# %%
num_brew = numb
plt.scatter(number_breweries, population, marker="o", facecolors="orange", edgecolors="black")

plt.ylim(50000, 40000000)

# Set the upper and lower limits of our x axis
plt.xlim(0, 910)

# Create a title, x label, and y label for our chart
plt.title("Number of Breweries vs. Population")
plt.xlabel("Number of Breweries")
plt.ylabel("Population")

plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-2dc68c379ef0> in <module>
# ----> 1 plt.scatter(number_breweries, population, marker="o", facecolors="orange", edgecolors="black")
#       2
#       3 plt.ylim(50000, 40000000)
#       4
#       5 # Set the upper and lower limits of our x axis
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
grouped = merge_table.groupby("Name")
median_age = grouped["Median Age"].mean()

plt.scatter(median_age, number_breweries, marker="*", facecolors="violet", edgecolors="black")

plt.ylim(0, 910)

# Set the upper and lower limits of our x axis
plt.xlim(34, 46)

# Create a tit;e, x label, and y label for our chart
plt.title("Age vs. Number of Breweries")
plt.xlabel("Median Age")
plt.ylabel("Breweries in State")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
grouped = merge_table.groupby("Name")
income = grouped["Household Income"].mean()

plt.scatter(number_breweries, income, marker="x", facecolors="deeppink", edgecolors="black")

plt.ylim(35000, 80000)

# Set the upper and lower limits of our x axis
plt.xlim(0, 910)

# Create a title, x label, and y label for our chart
plt.title("Number of Breweries vs. Income")
plt.xlabel("Number of Breweries")
plt.ylabel("Income")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
